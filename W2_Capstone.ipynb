# %% [markdown]
# <h1>Capstone Project</h1>
# <h2>Description</h2>

# %% [markdown]
# User planning to move another location based on his new job offer, User has to solve with location data and Select a location data provider based on its features.

# %%
import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
